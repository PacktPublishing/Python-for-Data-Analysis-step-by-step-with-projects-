# %% [markdown]
# # Modifying values

# %%
import pandas as pd
hero = pd.read_pickle('hero.pkl')

# %%
hero.head()
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2    Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3         Amazo   Male       red  Android          -     257  DC Comics
# 4    Animal Man   Male      blue    Human      Blond     183  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
# 2      good    90.0    Alan Scott  ...         False            False
# 3       bad   173.0         Amazo  ...         False            False
# 4      good    83.0    Animal Man  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# ...

# %%
hero.loc[2, 'race']
# Out:
# '-'

# %%
hero.loc[2, 'race'] = 'Unknown'

# %%
hero.head()
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2    Alan Scott   Male      blue  Unknown      Blond     180  DC Comics
# 3         Amazo   Male       red  Android          -     257  DC Comics
# 4    Animal Man   Male      blue    Human      Blond     183  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
# 2      good    90.0    Alan Scott  ...         False            False
# 3       bad   173.0         Amazo  ...         False            False
# 4      good    83.0    Animal Man  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# ...

# %%
hero.iloc[2, 3]
# Out:
# 'Unknown'

# %%
hero.iloc[2, 3] = '-'

# %%
hero.head()
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2    Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3         Amazo   Male       red  Android          -     257  DC Comics
# 4    Animal Man   Male      blue    Human      Blond     183  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
# 2      good    90.0    Alan Scott  ...         False            False
# 3       bad   173.0         Amazo  ...         False            False
# 4      good    83.0    Animal Man  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# ...

# %%
hero['race'] == '-'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 532    False
# 533     True
# 534    False
# 535    False
# 536    False
# Name: race, Length: 537, dtype: boolean

# %%
hero.loc[hero['race'] == '-', 'race']
# Out:
# 2      -
# 6      -
# 11     -
# 12     -
# 13     -
#       ..
# 526    -
# 527    -
# 529    -
# 531    -
# 533    -
# Name: race, Length: 193, dtype: string

# %%
hero.loc[hero['race'] == '-', 'race'] = 'Unknown'

# %%
hero[hero['race'] == 'Unknown']
# Out:
#            name  gender eye color     race hair color  height      publisher  \
# 2    Alan Scott    Male      blue  Unknown      Blond     180      DC Comics
# 6      Aquababy    Male      blue  Unknown      Blond     -99      DC Comics
# 11         Atom    Male      blue  Unknown        Red     178      DC Comics
# 12         Atom    Male         -  Unknown          -     -99      DC Comics
# 13    Atom Girl  Female     black  Unknown      Black     168      DC Comics
# ..          ...     ...       ...      ...        ...     ...            ...
# 526     Watcher    Male         -  Unknown          -     -99  Marvel Comics
# 527   Weapon XI    Male         -  Unknown          -     -99  Marvel Comics
# 529   Wolfsbane  Female     green  Unknown     Auburn     366  Marvel Comics
# 531  Wonder Man    Male       red  Unknown      Black     188  Marvel Comics
# 533       X-Man    Male      blue  Unknown      Brown     175  Marvel Comics
#
# ...

# %%
hero.loc[533]
# Out:
# name                       X-Man
# gender                      Male
# eye color                   blue
# race                     Unknown
# hair color                 Brown
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: 533, Length: 177, dtype: object

# %%
hero.shape
# Out:
# (537, 177)

# %%
hero.loc[10000] = hero.loc[533]

# %%
hero.shape
# Out:
# (538, 177)

# %%
hero.tail()
# Out:
#                   name  gender eye color         race        hair color  \
# 533              X-Man    Male      blue      Unknown             Brown
# 534       Yellowjacket    Male      blue        Human             Blond
# 535    Yellowjacket II  Female      blue        Human  Strawberry Blond
# 536               Ymir    Male     white  Frost Giant           No Hair
# 10000            X-Man    Male      blue      Unknown             Brown
#
#        height      publisher alignment  weight        hero name  ...  \
# 533       175  Marvel Comics      good    61.0            X-Man  ...
# 534       183  Marvel Comics      good    83.0     Yellowjacket  ...
# 535       165  Marvel Comics      good    52.0  Yellowjacket II  ...
# 536       305  Marvel Comics      good   -99.0             Ymir  ...
# 10000     175  Marvel Comics      good    61.0            X-Man  ...
#
#        web creation  reality warping  odin force  symbiote costume  \
# ...

# %%
# hero.iloc[10000] = hero.loc[533] IndexError: iloc cannot enlarge its target object

# %%
hero.iloc[536] = hero.loc[533]

# %%
hero.tail()
# Out:
#                   name  gender eye color     race        hair color  height  \
# 533              X-Man    Male      blue  Unknown             Brown     175
# 534       Yellowjacket    Male      blue    Human             Blond     183
# 535    Yellowjacket II  Female      blue    Human  Strawberry Blond     165
# 536              X-Man    Male      blue  Unknown             Brown     175
# 10000            X-Man    Male      blue  Unknown             Brown     175
#
#            publisher alignment  weight        hero name  ...  web creation  \
# 533    Marvel Comics      good    61.0            X-Man  ...         False
# 534    Marvel Comics      good    83.0     Yellowjacket  ...         False
# 535    Marvel Comics      good    52.0  Yellowjacket II  ...         False
# 536    Marvel Comics      good    61.0            X-Man  ...         False
# 10000  Marvel Comics      good    61.0            X-Man  ...         False
#
# ...

# %%
hero['height'] #cm
# Out:
# 0        185
# 1        185
# 2        180
# 3        257
# 4        183
#         ...
# 533      175
# 534      183
# 535      165
# 536      175
# 10000    175
# Name: height, Length: 538, dtype: int64

# %%
hero['height']*0.0328084 # convert to feet
# Out:
# 0        6.069554
# 1        6.069554
# 2        5.905512
# 3        8.431759
# 4        6.003937
#            ...
# 533      5.741470
# 534      6.003937
# 535      5.413386
# 536      5.741470
# 10000    5.741470
# Name: height, Length: 538, dtype: float64

# %%
hero['height'] = hero['height']*0.0328084

# %%
hero['height']
# Out:
# 0        6.069554
# 1        6.069554
# 2        5.905512
# 3        8.431759
# 4        6.003937
#            ...
# 533      5.741470
# 534      6.003937
# 535      5.413386
# 536      5.741470
# 10000    5.741470
# Name: height, Length: 538, dtype: float64

# %%
hero.select_dtypes(include='number')
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      8.431759   173.0
# 4      6.003937    83.0
# ...         ...     ...
# 533    5.741470    61.0
# 534    6.003937    83.0
# 535    5.413386    52.0
# 536    5.741470    61.0
# 10000  5.741470    61.0
#
# [538 rows x 2 columns]

# %%
numeric_cols = hero.select_dtypes(include='number').columns

# %%
numeric_cols
# Out:
# Index(['height', 'weight'], dtype='object')

# %%
type(numeric_cols)
# Out:
# pandas.core.indexes.base.Index

# %%
hero[['height', 'weight']]
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      8.431759   173.0
# 4      6.003937    83.0
# ...         ...     ...
# 533    5.741470    61.0
# 534    6.003937    83.0
# 535    5.413386    52.0
# 536    5.741470    61.0
# 10000  5.741470    61.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols]
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      8.431759   173.0
# 4      6.003937    83.0
# ...         ...     ...
# 533    5.741470    61.0
# 534    6.003937    83.0
# 535    5.413386    52.0
# 536    5.741470    61.0
# 10000  5.741470    61.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols] * 100
# Out:
#           height   weight
# 0      606.95540   9000.0
# 1      606.95540   8800.0
# 2      590.55120   9000.0
# 3      843.17588  17300.0
# 4      600.39372   8300.0
# ...          ...      ...
# 533    574.14700   6100.0
# 534    600.39372   8300.0
# 535    541.33860   5200.0
# 536    574.14700   6100.0
# 10000  574.14700   6100.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols] = hero[numeric_cols] * 100
hero[numeric_cols]
# Out:
#           height   weight
# 0      606.95540   9000.0
# 1      606.95540   8800.0
# 2      590.55120   9000.0
# 3      843.17588  17300.0
# 4      600.39372   8300.0
# ...          ...      ...
# 533    574.14700   6100.0
# 534    600.39372   8300.0
# 535    541.33860   5200.0
# 536    574.14700   6100.0
# 10000  574.14700   6100.0
#
# [538 rows x 2 columns]

# %%
hero[numeric_cols] = hero[numeric_cols] / 100

# %%
hero[numeric_cols] # height in feet, weight in kg
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      8.431759   173.0
# 4      6.003937    83.0
# ...         ...     ...
# 533    5.741470    61.0
# 534    6.003937    83.0
# 535    5.413386    52.0
# 536    5.741470    61.0
# 10000  5.741470    61.0
#
# [538 rows x 2 columns]

# %%
# bmi = weight(kg) / [height(m)]^2
hero['weight']/(hero['height']/3.28084)**2
# Out:
# 0        26.296567
# 1        25.712199
# 2        27.777778
# 3        26.192675
# 4        24.784258
#            ...
# 533      19.918367
# 534      24.784258
# 535      19.100092
# 536      19.918367
# 10000    19.918367
# Length: 538, dtype: float64

# %%
hero['bmi'] = hero['weight']/(hero['height']/3.28084)**2

# %%
hero.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero name',
#        ...
#        'reality warping', 'odin force', 'symbiote costume', 'speed force',
#        'phoenix force', 'molecular dissipation', 'vision - cryo',
#        'omnipresent', 'omniscient', 'bmi'],
#       dtype='object', length=178)

# %%
hero.head(10)
# Out:
#            name gender eye color           race hair color    height  \
# 0      Abin Sur   Male      blue        Ungaran    No Hair  6.069554
# 1  Adam Strange   Male      blue          Human      Blond  6.069554
# 2    Alan Scott   Male      blue        Unknown      Blond  5.905512
# 3         Amazo   Male       red        Android          -  8.431759
# 4    Animal Man   Male      blue          Human      Blond  6.003937
# 5  Anti-Monitor   Male    yellow  God / Eternal    No Hair  2.001312
# 6      Aquababy   Male      blue        Unknown      Blond -3.248032
# 7       Aqualad   Male      blue      Atlantean      Black  5.839895
# 8       Aquaman   Male      blue      Atlantean      Blond  6.069554
# 9         Atlas   Male      blue  God / Eternal      Brown  6.496063
#
#    publisher alignment  weight     hero name  ...  reality warping  \
# 0  DC Comics      good    90.0      Abin Sur  ...            False
# 1  DC Comics      good    88.0  Adam Strange  ...            False
# ...

# %% [markdown]
# # Making a copy

# %%
hero_ref = hero
hero_copy = hero.copy()

# %%
hero['original_ind'] = True
hero_ref['ref_ind'] = True
hero_copy['copy_ind'] = True

# %%
hero.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero name',
#        ...
#        'symbiote costume', 'speed force', 'phoenix force',
#        'molecular dissipation', 'vision - cryo', 'omnipresent', 'omniscient',
#        'bmi', 'original_ind', 'ref_ind'],
#       dtype='object', length=180)

# %%
hero_ref.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero name',
#        ...
#        'symbiote costume', 'speed force', 'phoenix force',
#        'molecular dissipation', 'vision - cryo', 'omnipresent', 'omniscient',
#        'bmi', 'original_ind', 'ref_ind'],
#       dtype='object', length=180)

# %%
hero_copy.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero name',
#        ...
#        'odin force', 'symbiote costume', 'speed force', 'phoenix force',
#        'molecular dissipation', 'vision - cryo', 'omnipresent', 'omniscient',
#        'bmi', 'copy_ind'],
#       dtype='object', length=179)

# %%
hero_ref is hero
# Out:
# True

# %%
hero_copy is hero
# Out:
# False

# %% [markdown]
# # Sorting data

# %%
hero.head()
# Out:
#            name gender eye color     race hair color    height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair  6.069554  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond  6.069554  DC Comics
# 2    Alan Scott   Male      blue  Unknown      Blond  5.905512  DC Comics
# 3         Amazo   Male       red  Android          -  8.431759  DC Comics
# 4    Animal Man   Male      blue    Human      Blond  6.003937  DC Comics
#
#   alignment  weight     hero name  ...  symbiote costume  speed force  \
# 0      good    90.0      Abin Sur  ...             False        False
# 1      good    88.0  Adam Strange  ...             False        False
# 2      good    90.0    Alan Scott  ...             False        False
# 3       bad   173.0         Amazo  ...             False        False
# 4      good    83.0    Animal Man  ...             False        False
#
#    phoenix force  molecular dissipation  vision - cryo  omnipresent  \
# ...

# %%
hero.sort_values(by='race')
# Out:
#                  name  gender eye color           race hair color    height  \
# 246         Blackwulf    Male       red          Alien      White  6.167979
# 468     Silver Surfer    Male     white          Alien    No Hair  6.332021
# 66           Doomsday    Male       red          Alien      White  8.005250
# 95             Indigo  Female         -          Alien     Purple -3.248032
# 218            Ardina  Female     white          Alien     Orange  6.332021
# ...               ...     ...       ...            ...        ...       ...
# 250          Blizzard    Male         -        Unknown          - -3.248032
# 10000           X-Man    Male      blue        Unknown      Brown  5.741470
# 247             Blade    Male     brown        Vampire      Black  6.167979
# 323            Gamora  Female    yellow  Zen-Whoberian      Black  6.003937
# 170    Solomon Grundy    Male     black         Zombie      White  9.153544
#
# ...

# %%
hero.sort_values(by='race', ascending=False)
# Out:
#                name  gender eye color           race hair color    height  \
# 170  Solomon Grundy    Male     black         Zombie      White  9.153544
# 323          Gamora  Female    yellow  Zen-Whoberian      Black  6.003937
# 247           Blade    Male     brown        Vampire      Black  6.167979
# 319          Frenzy  Female     brown        Unknown      Black  6.922572
# 125          Misfit  Female      blue        Unknown        Red -3.248032
# ..              ...     ...       ...            ...        ...       ...
# 95           Indigo  Female         -          Alien     Purple -3.248032
# 218          Ardina  Female     white          Alien     Orange  6.332021
# 271         Century    Male     white          Alien      White  6.594488
# 307        Evilhawk    Male       red          Alien      Black  6.266404
# 66         Doomsday    Male       red          Alien      White  8.005250
#
#          publisher alignment  weight       hero name  ...  symbiote costume  \
# ...

# %%
hero.sort_values(by='bmi', ascending=False).head()
# Out:
#             name  gender eye color               race hair color    height  \
# 509  Utgard-Loki    Male      blue        Frost Giant      White  0.492126
# 81       Giganta  Female     green            Unknown        Red  2.066929
# 441     Red Hulk    Male    yellow  Human / Radiation      Black  6.988189
# 60      Darkseid    Male       red            New God    No Hair  8.759843
# 386  Machine Man       -       red            Unknown      Black  6.003937
#
#          publisher alignment  weight    hero name  ...  symbiote costume  \
# 509  Marvel Comics       bad    58.0  Utgard-Loki  ...             False
# 81       DC Comics       bad   630.0      Giganta  ...             False
# 441  Marvel Comics   neutral   630.0     Red Hulk  ...             False
# 60       DC Comics       bad   817.0     Darkseid  ...             False
# 386  Marvel Comics      good   383.0  Machine Man  ...             False
#
#      speed force  phoenix force  molecular dissipation  vision - cryo  \
# ...

# %%
hero[['race', 'height']].sort_values(by=['race', 'height'])
# Out:
#               race     height
# 95           Alien  -3.248032
# 246          Alien   6.167979
# 307          Alien   6.266404
# 218          Alien   6.332021
# 468          Alien   6.332021
# ..             ...        ...
# 450        Unknown  10.006562
# 529        Unknown  12.007874
# 247        Vampire   6.167979
# 323  Zen-Whoberian   6.003937
# 170         Zombie   9.153544
#
# [538 rows x 2 columns]

# %%
hero[['race', 'height']].sort_values(by=['height', 'race'])
# Out:
#                 race     height
# 95             Alien  -3.248032
# 107           Animal  -3.248032
# 200    Cosmic Entity  -3.248032
# 378    Cosmic Entity  -3.248032
# 426    Cosmic Entity  -3.248032
# ..               ...        ...
# 403           Cyborg  12.007874
# 529          Unknown  12.007874
# 335   Flora Colossus  22.998688
# 321    Cosmic Entity  28.740158
# 313  Kakarantharaian  31.988190
#
# [538 rows x 2 columns]

# %%
hero[['race', 'height']].sort_values(by=['height', 'race'], ascending=[True, False])
# Out:
#                 race     height
# 6            Unknown  -3.248032
# 12           Unknown  -3.248032
# 15           Unknown  -3.248032
# 16           Unknown  -3.248032
# 18           Unknown  -3.248032
# ..               ...        ...
# 529          Unknown  12.007874
# 403           Cyborg  12.007874
# 335   Flora Colossus  22.998688
# 321    Cosmic Entity  28.740158
# 313  Kakarantharaian  31.988190
#
# [538 rows x 2 columns]

# %%
hero.nlargest(n=10, columns='height')
# Out:
#                name  gender eye color             race hair color     height  \
# 313   Fin Fang Foom    Male       red  Kakarantharaian    No Hair  31.988190
# 321        Galactus    Male     black    Cosmic Entity      Black  28.740158
# 335           Groot    Male    yellow   Flora Colossus          -  22.998688
# 403           MODOK    Male     white           Cyborg     Brownn  12.007874
# 529       Wolfsbane  Female     green          Unknown     Auburn  12.007874
# 427       Onslaught    Male       red           Mutant    No Hair  10.006562
# 450       Sasquatch    Male       red          Unknown     Orange  10.006562
# 365      Juggernaut    Male      blue            Human        Red   9.416011
# 170  Solomon Grundy    Male     black           Zombie      White   9.153544
# 60         Darkseid    Male       red          New God    No Hair   8.759843
#
#          publisher alignment  weight       hero name  ...  symbiote costume  \
# ...

# %%
hero.sort_values(by='height', ascending=False).head(10)
# Out:
#                name  gender eye color             race hair color     height  \
# 313   Fin Fang Foom    Male       red  Kakarantharaian    No Hair  31.988190
# 321        Galactus    Male     black    Cosmic Entity      Black  28.740158
# 335           Groot    Male    yellow   Flora Colossus          -  22.998688
# 403           MODOK    Male     white           Cyborg     Brownn  12.007874
# 529       Wolfsbane  Female     green          Unknown     Auburn  12.007874
# 427       Onslaught    Male       red           Mutant    No Hair  10.006562
# 450       Sasquatch    Male       red          Unknown     Orange  10.006562
# 365      Juggernaut    Male      blue            Human        Red   9.416011
# 170  Solomon Grundy    Male     black           Zombie      White   9.153544
# 60         Darkseid    Male       red          New God    No Hair   8.759843
#
#          publisher alignment  weight       hero name  ...  symbiote costume  \
# ...

# %%
hero.nsmallest(10, 'height')
# Out:
#            name  gender eye color           race hair color    height  \
# 6      Aquababy    Male      blue        Unknown      Blond -3.248032
# 12         Atom    Male         -        Unknown          - -3.248032
# 15     Atom III    Male         -        Unknown        Red -3.248032
# 16      Atom IV    Male     brown        Unknown      Black -3.248032
# 17       Azrael    Male     brown          Human      Black -3.248032
# 18        Aztar    Male         -        Unknown          - -3.248032
# 20      Batgirl  Female         -        Unknown          - -3.248032
# 29       Ben 10    Male         -        Unknown          - -3.248032
# 35  Black Flash    Male         -  God / Eternal          - -3.248032
# 38  Blue Beetle    Male      blue        Unknown      Brown -3.248032
#
#     publisher alignment  weight    hero name  ...  symbiote costume  \
# 6   DC Comics      good     NaN     Aquababy  ...             False
# ...

# %%
hero[hero['height'] > 0].nsmallest(10, 'height')
# Out:
#                   name  gender     eye color           race hair color  \
# 509        Utgard-Loki    Male          blue    Frost Giant      White
# 256        Bloodwraith    Male         white        Unknown    No Hair
# 5         Anti-Monitor    Male        yellow  God / Eternal    No Hair
# 81             Giganta  Female         green        Unknown        Red
# 108             Krypto    Male          blue     Kryptonian      White
# 445     Rocket Raccoon    Male         brown         Animal      Brown
# 158            Robin V    Male          blue          Human      Black
# 318  Franklin Richards    Male          blue         Mutant      Blond
# 112      Lightning Lad    Male          blue        Unknown        Red
# 358     Jack of Hearts    Male  blue / white          Human      Brown
#
#        height      publisher alignment  weight          hero name  ...  \
# 509  0.492126  Marvel Comics       bad    58.0        Utgard-Loki  ...
# ...

# %%
# hero.nsmallest(10, 'race') #TypeError: Column 'race' has dtype object, cannot use method 'nsmallest' with this dtype
